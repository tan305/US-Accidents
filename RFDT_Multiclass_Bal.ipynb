# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
import numpy as np
import pandas as pd
from pyspark.sql.types import *
from pyspark.sql.functions import *
import matplotlib.pyplot as plt
from pyspark.sql import functions as fn
from pyspark.ml import feature, regression, evaluation, Pipeline
import seaborn as sns
from pyspark.ml.feature import VectorAssembler
from pyspark.ml import Pipeline
from pyspark.ml.regression import LinearRegression
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import LogisticRegression,RandomForestClassifier
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
from pyspark.ml import Pipeline
from pyspark.ml.feature import OneHotEncoder, OneHotEncoderModel, StringIndexer, VectorAssembler
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext

# %%
# Do not delete or change this cell

import os

# Define a function to determine if we are running on data bricks
# Return true if running in the data bricks environment, false otherwise
def is_databricks():
    # get the databricks runtime version
    db_env = os.getenv("DATABRICKS_RUNTIME_VERSION")
    
    # if running on data bricks
    if db_env != None:
        return True
    else:
        return False

# Define a function to read the data file.  The full path data file name is constructed
# by checking runtime environment variables to determine if the runtime environment is 
# databricks, or a student's personal computer.  The full path file name is then
# constructed based on the runtime env.
# 
# Params
#   data_file_name: The base name of the data file to load
# 
# Returns the full path file name based on the runtime env
#
def get_training_filename(data_file_name):    
    # if running on data bricks
    if is_databricks():
        # build the full path file name assuming data brick env
        full_path_name = "/FileStore/tables/%s" % data_file_name
    # else the data is assumed to be in the same dir as this notebook
    else:
        # Assume the student is running on their own computer and load the data
        # file from the same dir as this notebook
        full_path_name = data_file_name
    
    # return the full path file name to the caller
    return full_path_name

# %%
# Loading the training data

us_train_cat = spark.read.csv(get_training_filename('USAccident_balanced_train_categorical.csv'), header = True, inferSchema = True)

# %%
# Loading the testing data

us_test_cat = spark.read.csv(get_training_filename('USAccident_validation_categorical.csv'), header = True, inferSchema = True)

# %%
# Counting the Distinct Severity of Accidents in training data

us_train_cat.agg(countDistinct("Severity")).show()
# Out:
# +------------------------+
# |count(DISTINCT Severity)|
# +------------------------+
# |                       3|
# +------------------------+

# %%
# Counting the Distinct Severity of Accidents in testing data

us_test_cat.agg(countDistinct("Severity")).show()
# Out:
# +------------------------+
# |count(DISTINCT Severity)|
# +------------------------+
# |                       3|
# +------------------------+

# %%
# Checking the balance of data in training dataset

us_train_cat.groupBy('Severity').count().show()
# Out:
# +--------+------+
# |Severity| count|
# +--------+------+
# |       3|234316|
# |       4|219321|
# |       2|263797|
# +--------+------+

# %%
# Checking the balance of data in testing dataset

us_test_cat.groupBy('Severity').count().show()
# Out:
# +--------+------+
# |Severity| count|
# +--------+------+
# |       3| 58293|
# |       4|  6115|
# |       2|131571|
# +--------+------+

# %%
# Assigning label 0 to severity 2 label for test dataset

us_test_cat=us_test_cat.withColumn("Severity",when(us_test_cat["Severity"]==2,0).otherwise(us_test_cat["Severity"]))

# %%
# Assigning label 0 to severity 2 label for train dataset

us_train_cat=us_train_cat.withColumn("Severity",when(us_train_cat["Severity"]==2,0).otherwise(us_train_cat["Severity"]))

# %%
# Assigning label 1 to severity 3 label for test dataset

us_test_cat=us_test_cat.withColumn("Severity",when(us_test_cat["Severity"]==3,1).otherwise(us_test_cat["Severity"]))

# %%
# Assigning label 1 to severity 3 label for train dataset

us_train_cat=us_train_cat.withColumn("Severity",when(us_train_cat["Severity"]==3,1).otherwise(us_train_cat["Severity"]))

# %%
# Assigning label 2 to severity 4 label for test dataset

us_test_cat=us_test_cat.withColumn("Severity",when(us_test_cat["Severity"]==4,2).otherwise(us_test_cat["Severity"]))

# %%
# Assigning label 2 to severity 4 label for train dataset

us_train_cat=us_train_cat.withColumn("Severity",when(us_train_cat["Severity"]==4,2).otherwise(us_train_cat["Severity"]))

# %%
# Vector Assembler to convert all features except Severity to a single column features for feeding it to input of model

va = VectorAssembler().setInputCols([i for i in us_train_cat.columns if i!='Severity']).setOutputCol('features')

# %%
# String Indexer to assign target Variable Severity name Label needed for the model to predict

label_stringIdx = StringIndexer(inputCol="Severity", outputCol="label")

# %%
# Multiclass Evaluator to evaluate the performance of the model with 3 class prediction 

from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")

# %% [markdown]
# # Multiclass RF Base Model

# %%
# Create an initial RandomForest model
rf = RandomForestClassifier(labelCol="label", featuresCol="features",seed=42)

# Creating pipeline for RF Base Model 

rfModel = Pipeline(stages=[label_stringIdx,va, rf])

# %%
# Train RF base model with Training Data

rf_fit = rfModel.fit(us_train_cat)

# %%
# Evaluation of model using Multiclass Evaluator on Test data for accuracy as metric

print("Accuracy is", evaluator.evaluate(rf_fit.transform(us_test_cat)))
# Out:
# Accuracy is 0.5591976691380199

# %%
# Prediction output from the model to pandas

prediction_rfmu=(rf_fit.transform(us_test_cat)).toPandas()["prediction"]

# %%
# True Labels from test data for Target Variable

true_labels=us_test_cat.toPandas()["Severity"]

# %%
# Initializing Classification Report from sklearn

from sklearn.metrics import classification_report

# %%
# Classification Report Generation for all metrics display at once

print(classification_report(y_pred=prediction_rfmu,y_true=true_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.44      0.59    131571
#            1       0.49      0.80      0.61     58293
#            2       0.14      0.93      0.25      6115
#
#    micro avg       0.56      0.56      0.56    195979
#    macro avg       0.52      0.72      0.48    195979
# weighted avg       0.77      0.56      0.59    195979

# %%
# Creating Pandas Dataframe for Features and their Importance of RF Base Model for Multiclass Classification

pd.set_option('display.max_rows', None)
feat_imp_tuned_rfm = pd.DataFrame(list(zip([i for i in us_train_cat.columns if i!='Severity'], rf_fit.stages[-1].featureImportances)),
            columns = ['column', 'weight']).sort_values('weight',ascending=False)

# %%
# Plotting top 10 Features from Feature Importance of RF Base Model for Multiclass Classification

plt.figure(figsize=(10,10))
sns.barplot(x=feat_imp_tuned_rfm['column'][:10], y=feat_imp_tuned_rfm['weight'][:10],data=feat_imp_tuned_rfm)
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Weights")
plt.title("Top 10 Features based on Importance from Random Forest")
# Out:
# Text(0.5,1,'Top 10 Features based on Importance from Random Forest')

# %% [markdown]
# # Multiclass RF Grid Search Model

# %%
# Create an initial RandomForest model.

rf_new = RandomForestClassifier(labelCol="label", featuresCol="features",seed=42)

# Creating pipeline for RF Grid Model 

rfModel_new = Pipeline(stages=[label_stringIdx,va, rf_new])

# %%
# Creating Grid Search for Hyper Parameter Tuning

paramGrid_rf = ParamGridBuilder().addGrid(rf_new.numTrees, [10, 25, 60]).addGrid(rf_new.maxDepth, [3, 6, 10]).addGrid(rf_new.impurity,["entropy", "gini"]).build()

# %%
# Cross Validator with 5 fold and Grid Search to fit the training data

cv_rf = CrossValidator(estimator=rfModel_new, estimatorParamMaps=paramGrid_rf, evaluator=evaluator, numFolds=5,seed=42).fit(us_train_cat)

# %%
# Transform Test data using Cross Validation Pipeline Built earlier for prediction of Test data

pred_rft = cv_rf.transform(us_test_cat)

# %%
# Evaluation of model using Multiclass Evaluator on Test data for Accuracy calculation

print("Accuracy is ",evaluator.evaluate(pred_rft))
# Out:
# Accuracy is  0.5753575638206134

# %%
# Prediction output from the model to pandas

prediction_rf=cv_rf.transform(us_test_cat).toPandas()["prediction"]

# %%
# True Labels from test data for Target Variable

true_labels=us_test_cat.toPandas()["Severity"]

# %%
# Initializing Classification Report from sklearn

from sklearn.metrics import classification_report

# %%
# Classification Report Generation for all metrics display at once

print(classification_report(y_pred=prediction_rf,y_true=true_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.46      0.62    131571
#            1       0.51      0.79      0.62     58293
#            2       0.15      0.94      0.25      6115
#
#    micro avg       0.58      0.58      0.58    195979
#    macro avg       0.53      0.73      0.50    195979
# weighted avg       0.78      0.58      0.61    195979

# %%
# Best Model Hyper Parameters after tuning

cv_rf.bestModel.stages[-1].extractParamMap()
# Out:
# {Param(parent='RandomForestClassifier_fb004e563347', name='cacheNodeIds', doc='If false, the algorithm will pass trees to executors to match instances with nodes. If true, the algorithm will cache node IDs for each instance. Caching can speed up training of deeper trees.'): False,
#  Param(parent='RandomForestClassifier_fb004e563347', name='checkpointInterval', doc='set checkpoint interval (>= 1) or disable checkpoint (-1). E.g. 10 means that the cache will get checkpointed every 10 iterations. Note: this setting will be ignored if the checkpoint directory is not set in the SparkContext'): 10,
#  Param(parent='RandomForestClassifier_fb004e563347', name='featureSubsetStrategy', doc='The number of features to consider for splits at each tree node. Supported options: auto, all, onethird, sqrt, log2, (0.0-1.0], [1-n].'): 'auto',
#  Param(parent='RandomForestClassifier_fb004e563347', name='featuresCol', doc='features column name'): 'features',
#  Param(parent='RandomForestClassifier_fb004e563347', name='impurity', doc='Criterion used for information gain calculation (case-insensitive). Supported options: entropy, gini'): 'gini',
#  Param(parent='RandomForestClassifier_fb004e563347', name='labelCol', doc='label column name'): 'label',
#  Param(parent='RandomForestClassifier_fb004e563347', name='maxBins', doc='Max number of bins for discretizing continuous features.  Must be >=2 and >= number of categories for any categorical feature.'): 32,
#  Param(parent='RandomForestClassifier_fb004e563347', name='maxDepth', doc='Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes.'): 10,
#  Param(parent='RandomForestClassifier_fb004e563347', name='maxMemoryInMB', doc='Maximum memory in MB allocated to histogram aggregation.'): 256,
#  Param(parent='RandomForestClassifier_fb004e563347', name='minInfoGain', doc='Minimum information gain for a split to be considered at a tree node.'): 0.0,
#  Param(parent='RandomForestClassifier_fb004e563347', name='minInstancesPerNode', doc='Minimum number of instances each child must have after split.  If a split causes the left or right child to have fewer than minInstancesPerNode, the split will be discarded as invalid. Should be >= 1.'): 1,
#  Param(parent='RandomForestClassifier_fb004e563347', name='numTrees', doc='Number of trees to train (>= 1)'): 60,
#  Param(parent='RandomForestClassifier_fb004e563347', name='predictionCol', doc='prediction column name'): 'prediction',
#  Param(parent='RandomForestClassifier_fb004e563347', name='probabilityCol', doc='Column name for predicted class conditional probabilities. Note: Not all models output well-calibrated probability estimates! These probabilities should be treated as confidences, not precise probabilities'): 'probability',
#  Param(parent='RandomForestClassifier_fb004e563347', name='rawPredictionCol', doc='raw prediction (a.k.a. confidence) column name'): 'rawPrediction',
#  Param(parent='RandomForestClassifier_fb004e563347', name='seed', doc='random seed'): 42,
#  Param(parent='RandomForestClassifier_fb004e563347', name='subsamplingRate', doc='Fraction of the training data used for learning each decision tree, in range (0, 1].'): 1.0}

# %%
# Feature Importance Sparse Matrix

cv_rf.bestModel.stages[-1].featureImportances
# Out:
# SparseVector(48, {0: 0.0004, 1: 0.001, 3: 0.0001, 4: 0.0001, 5: 0.0001, 6: 0.0001, 7: 0.0, 8: 0.0002, 9: 0.0002, 10: 0.0001, 11: 0.0043, 13: 0.0001, 14: 0.0003, 15: 0.0, 16: 0.2714, 17: 0.0037, 18: 0.0019, 19: 0.0049, 20: 0.0006, 21: 0.0038, 22: 0.0005, 23: 0.0015, 25: 0.0139, 26: 0.0001, 27: 0.0068, 28: 0.0, 29: 0.0003, 30: 0.0, 31: 0.0012, 32: 0.0045, 33: 0.0, 34: 0.0575, 35: 0.0083, 36: 0.0047, 37: 0.2724, 38: 0.0861, 39: 0.0008, 40: 0.003, 41: 0.0136, 42: 0.2007, 43: 0.001, 44: 0.0034, 45: 0.0041, 46: 0.0066, 47: 0.0156})

# %%
# Creating Pandas Dataframe for Features and their Importance of RF Grid Model for Multiclass Classification

pd.set_option('display.max_rows', None)
feat_imp_tuned_rft = pd.DataFrame(list(zip([i for i in us_train_cat.columns if i!='Severity'], cv_rf.bestModel.stages[-1].featureImportances)),
            columns = ['column', 'weight']).sort_values('weight',ascending=False)

# %%
# Plotting top 10 Features from Feature Importance of RF Grid Model for Multiclass Classification

plt.figure(figsize=(10,10))
sns.barplot(x=feat_imp_tuned_rft['column'][:10], y=feat_imp_tuned_rft['weight'][:10],data=feat_imp_tuned_rft)
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Weights")
plt.title("Top 10 Features based on Importance from Random Forest Grid Model")
# Out:
# Text(0.5,1,'Top 10 Features based on Importance from Random Forest Grid Model')

# %%
# Tree from the best Model printing it 

print(cv_rf.bestModel.stages[-1].trees[3].toDebugString)
# Out:
# DecisionTreeClassificationModel (uid=dtc_7704b0d6a395) of depth 10 with 1001 nodes
#   If (feature 35 <= 3.5)
#    If (feature 36 <= 36.5)
#     If (feature 39 <= 0.5)
#      If (feature 5 <= 0.5)
#       If (feature 40 <= 5.5)
#        If (feature 36 <= 33.5)
#         If (feature 37 <= 0.5)
#          If (feature 9 <= 0.5)
#           If (feature 38 <= 0.5)
#            If (feature 22 <= 0.005)
#             Predict: 1.0
#            Else (feature 22 > 0.005)
#             Predict: 2.0
#           Else (feature 38 > 0.5)
#            If (feature 18 <= 85.5)
#             Predict: 0.0
#            Else (feature 18 > 85.5)
#             Predict: 1.0
#          Else (feature 9 > 0.5)
#           Predict: 2.0
#         Else (feature 37 > 0.5)
#          If (feature 27 <= 0.5)
#           If (feature 16 <= 5.0E-4)
#            If (feature 1 <= 0.5)
#             Predict: 1.0
#            Else (feature 1 > 0.5)
#             Predict: 2.0
#           Else (feature 16 > 5.0E-4)
#            Predict: 2.0
#          Else (feature 27 > 0.5)
#           If (feature 16 <= 0.8125)
#            If (feature 16 <= 0.6325000000000001)
#             Predict: 2.0
#            Else (feature 16 > 0.6325000000000001)
#             Predict: 1.0
#           Else (feature 16 > 0.8125)
#            If (feature 17 <= 62.5)
#             Predict: 1.0
#            Else (feature 17 > 62.5)
#             Predict: 2.0
#        Else (feature 36 > 33.5)
#         If (feature 16 <= 0.0055)
#          If (feature 42 <= 0.5)
#           If (feature 1 <= 0.5)
#            If (feature 41 <= 1.5)
#             Predict: 1.0
#            Else (feature 41 > 1.5)
#             Predict: 0.0
#           Else (feature 1 > 0.5)
#            If (feature 20 <= 3.25)
#             Predict: 0.0
#            Else (feature 20 > 3.25)
#             Predict: 1.0
#          Else (feature 42 > 0.5)
#           If (feature 21 <= 0.6)
#            If (feature 17 <= 76.9)
#             Predict: 0.0
#            Else (feature 17 > 76.9)
#             Predict: 1.0
#           Else (feature 21 > 0.6)
#            If (feature 34 <= 0.5)
#             Predict: 1.0
#            Else (feature 34 > 0.5)
#             Predict: 2.0
#         Else (feature 16 > 0.0055)
#          If (feature 13 <= 0.5)
#           Predict: 2.0
#          Else (feature 13 > 0.5)
#           Predict: 1.0
#       Else (feature 40 > 5.5)
#        If (feature 34 <= 0.5)
#         If (feature 42 <= 0.5)
#          If (feature 38 <= 0.5)
#           If (feature 18 <= 99.5)
#            Predict: 1.0
#           Else (feature 18 > 99.5)
#            If (feature 40 <= 7.5)
#             Predict: 1.0
#            Else (feature 40 > 7.5)
#             Predict: 0.0
#          Else (feature 38 > 0.5)
#           If (feature 41 <= 3.5)
#            Predict: 0.0
#           Else (feature 41 > 3.5)
#            If (feature 14 <= 0.5)
#             Predict: 1.0
#            Else (feature 14 > 0.5)
#             Predict: 0.0
#         Else (feature 42 > 0.5)
#          If (feature 47 <= 20.5)
#           If (feature 46 <= 0.5)
#            Predict: 1.0
#           Else (feature 46 > 0.5)
#            If (feature 42 <= 1.5)
#             Predict: 2.0
#            Else (feature 42 > 1.5)
#             Predict: 1.0
#          Else (feature 47 > 20.5)
#           If (feature 16 <= 0.0115)
#            Predict: 1.0
#           Else (feature 16 > 0.0115)
#            Predict: 2.0
#        Else (feature 34 > 0.5)
#         If (feature 1 <= 0.5)
#          If (feature 35 <= 1.5)
#           If (feature 17 <= 37.1)
#            Predict: 2.0
#           Else (feature 17 > 37.1)
#            If (feature 16 <= 0.0105)
#             Predict: 0.0
#            Else (feature 16 > 0.0105)
#             Predict: 2.0
#          Else (feature 35 > 1.5)
#           If (feature 42 <= 0.5)
#            If (feature 17 <= 51.45)
#             Predict: 1.0
#            Else (feature 17 > 51.45)
#             Predict: 0.0
#           Else (feature 42 > 0.5)
#            If (feature 47 <= 21.5)
#             Predict: 0.0
#            Else (feature 47 > 21.5)
#             Predict: 2.0
#         Else (feature 1 > 0.5)
#          If (feature 36 <= 22.5)
#           If (feature 16 <= 0.0105)
#            Predict: 0.0
#           Else (feature 16 > 0.0105)
#            Predict: 2.0
#          Else (feature 36 > 22.5)
#           If (feature 41 <= 4.5)
#            Predict: 1.0
#           Else (feature 41 > 4.5)
#            Predict: 0.0
#      Else (feature 5 > 0.5)
#       If (feature 47 <= 21.5)
#        Predict: 0.0
#       Else (feature 47 > 21.5)
#        Predict: 1.0
#     Else (feature 39 > 0.5)
#      If (feature 38 <= 0.5)
#       If (feature 17 <= 71.05)
#        If (feature 42 <= 0.5)
#         If (feature 25 <= 0.5)
#          If (feature 47 <= 20.5)
#           If (feature 34 <= 0.5)
#            Predict: 1.0
#           Else (feature 34 > 0.5)
#            If (feature 23 <= 0.5)
#             Predict: 0.0
#            Else (feature 23 > 0.5)
#             Predict: 1.0
#          Else (feature 47 > 20.5)
#           If (feature 41 <= 4.5)
#            If (feature 32 <= 0.5)
#             Predict: 1.0
#            Else (feature 32 > 0.5)
#             Predict: 0.0
#           Else (feature 41 > 4.5)
#            Predict: 1.0
#         Else (feature 25 > 0.5)
#          If (feature 39 <= 4.5)
#           If (feature 14 <= 0.5)
#            Predict: 0.0
#           Else (feature 14 > 0.5)
#            If (feature 18 <= 72.5)
#             Predict: 0.0
#            Else (feature 18 > 72.5)
#             Predict: 1.0
#          Else (feature 39 > 4.5)
#           If (feature 35 <= 0.5)
#            If (feature 17 <= 59.1)
#             Predict: 0.0
#            Else (feature 17 > 59.1)
#             Predict: 1.0
#           Else (feature 35 > 0.5)
#            If (feature 36 <= 22.5)
#             Predict: 0.0
#            Else (feature 36 > 22.5)
#             Predict: 1.0
#        Else (feature 42 > 0.5)
#         If (feature 16 <= 0.0105)
#          If (feature 11 <= 0.5)
#           If (feature 20 <= 9.5)
#            If (feature 25 <= 0.5)
#             Predict: 1.0
#            Else (feature 25 > 0.5)
#             Predict: 0.0
#           Else (feature 20 > 9.5)
#            Predict: 1.0
#          Else (feature 11 > 0.5)
#           If (feature 16 <= 5.0E-4)
#            Predict: 0.0
#           Else (feature 16 > 5.0E-4)
#            If (feature 39 <= 2.5)
#             Predict: 2.0
#            Else (feature 39 > 2.5)
#             Predict: 0.0
#         Else (feature 16 > 0.0105)
#          If (feature 41 <= 4.5)
#           If (feature 35 <= 0.5)
#            If (feature 37 <= 0.5)
#             Predict: 1.0
#            Else (feature 37 > 0.5)
#             Predict: 2.0
#           Else (feature 35 > 0.5)
#            If (feature 6 <= 0.5)
#             Predict: 2.0
#            Else (feature 6 > 0.5)
#             Predict: 1.0
#          Else (feature 41 > 4.5)
#           If (feature 21 <= 7.5)
#            Predict: 2.0
#           Else (feature 21 > 7.5)
#            If (feature 20 <= 0.625)
#             Predict: 1.0
#            Else (feature 20 > 0.625)
#             Predict: 2.0
#       Else (feature 17 > 71.05)
#        If (feature 18 <= 78.5)
#         If (feature 47 <= 22.5)
#          If (feature 21 <= 3.25)
#           If (feature 40 <= 3.5)
#            If (feature 41 <= 3.5)
#             Predict: 2.0
#            Else (feature 41 > 3.5)
#             Predict: 0.0
#           Else (feature 40 > 3.5)
#            If (feature 27 <= 0.5)
#             Predict: 2.0
#            Else (feature 27 > 0.5)
#             Predict: 1.0
#          Else (feature 21 > 3.25)
#           If (feature 17 <= 72.95)
#            If (feature 16 <= 0.0015)
#             Predict: 1.0
#            Else (feature 16 > 0.0015)
#             Predict: 2.0
#           Else (feature 17 > 72.95)
#            If (feature 16 <= 5.0E-4)
#             Predict: 1.0
#            Else (feature 16 > 5.0E-4)
#             Predict: 2.0
#         Else (feature 47 > 22.5)
#          If (feature 16 <= 1.070000026225)
#           If (feature 34 <= 0.5)
#            If (feature 19 <= 29.884999999999998)
#             Predict: 2.0
#            Else (feature 19 > 29.884999999999998)
#             Predict: 1.0
#           Else (feature 34 > 0.5)
#            If (feature 18 <= 67.5)
#             Predict: 2.0
#            Else (feature 18 > 67.5)
#             Predict: 0.0
#          Else (feature 16 > 1.070000026225)
#           If (feature 39 <= 4.5)
#            Predict: 2.0
#           Else (feature 39 > 4.5)
#            If (feature 40 <= 6.5)
#             Predict: 0.0
#            Else (feature 40 > 6.5)
#             Predict: 2.0
#        Else (feature 18 > 78.5)
#         If (feature 42 <= 0.5)
#          If (feature 21 <= 11.75)
#           If (feature 18 <= 93.5)
#            If (feature 34 <= 0.5)
#             Predict: 1.0
#            Else (feature 34 > 0.5)
#             Predict: 0.0
#           Else (feature 18 > 93.5)
#            If (feature 0 <= 0.5)
#             Predict: 1.0
#            Else (feature 0 > 0.5)
#             Predict: 2.0
#          Else (feature 21 > 11.75)
#           If (feature 19 <= 29.925)
#            Predict: 2.0
#           Else (feature 19 > 29.925)
#            Predict: 1.0
#         Else (feature 42 > 0.5)
#          If (feature 41 <= 5.5)
#           If (feature 40 <= 6.5)
#            Predict: 2.0
#           Else (feature 40 > 6.5)
#            If (feature 42 <= 1.5)
#             Predict: 2.0
#            Else (feature 42 > 1.5)
#             Predict: 1.0
#          Else (feature 41 > 5.5)
#           If (feature 42 <= 1.5)
#            Predict: 2.0
#           Else (feature 42 > 1.5)
#            Predict: 1.0
#      Else (feature 38 > 0.5)
#       If (feature 18 <= 62.5)
#        If (feature 42 <= 0.5)
#         If (feature 39 <= 6.5)
#          If (feature 35 <= 0.5)
#           Predict: 1.0
#          Else (feature 35 > 0.5)
#           Predict: 0.0
#         Else (feature 39 > 6.5)
#          Predict: 0.0
#        Else (feature 42 > 0.5)
#         If (feature 42 <= 1.5)
#          If (feature 18 <= 58.5)
#           If (feature 21 <= 3.25)
#            Predict: 0.0
#           Else (feature 21 > 3.25)
#            Predict: 2.0
#          Else (feature 18 > 58.5)
#           Predict: 2.0
#         Else (feature 42 > 1.5)
#          If (feature 17 <= 33.05)
#           Predict: 1.0
#          Else (feature 17 > 33.05)
#           Predict: 0.0
#       Else (feature 18 > 62.5)
#        If (feature 31 <= 0.5)
#         If (feature 22 <= 0.005)
#          If (feature 16 <= 0.0105)
#           If (feature 37 <= 0.5)
#            Predict: 0.0
#           Else (feature 37 > 0.5)
#            Predict: 2.0
#          Else (feature 16 > 0.0105)
#           Predict: 2.0
#         Else (feature 22 > 0.005)
#          If (feature 22 <= 0.035)
#           If (feature 42 <= 0.5)
#            If (feature 47 <= 22.5)
#             Predict: 1.0
#            Else (feature 47 > 22.5)
#             Predict: 0.0
#           Else (feature 42 > 0.5)
#            Predict: 2.0
#          Else (feature 22 > 0.035)
#           If (feature 42 <= 0.5)
#            If (feature 14 <= 0.5)
#             Predict: 0.0
#            Else (feature 14 > 0.5)
#             Predict: 1.0
#           Else (feature 42 > 0.5)
#            If (feature 3 <= 0.5)
#             Predict: 2.0
#            Else (feature 3 > 0.5)
#             Predict: 0.0
#        Else (feature 31 > 0.5)
#         If (feature 42 <= 0.5)
#          Predict: 0.0
#         Else (feature 42 > 0.5)
#          If (feature 16 <= 0.0105)
#           If (feature 40 <= 6.5)
#            Predict: 1.0
#           Else (feature 40 > 6.5)
#            Predict: 0.0
#          Else (feature 16 > 0.0105)
#           If (feature 35 <= 2.5)
#            Predict: 2.0
#           Else (feature 35 > 2.5)
#            Predict: 1.0
#    Else (feature 36 > 36.5)
#     If (feature 37 <= 0.5)
#      If (feature 38 <= 0.5)
#       If (feature 1 <= 0.5)
#        If (feature 18 <= 29.5)
#         If (feature 42 <= 2.5)
#          If (feature 16 <= 0.0105)
#           If (feature 16 <= 5.0E-4)
#            If (feature 3 <= 0.5)
#             Predict: 1.0
#            Else (feature 3 > 0.5)
#             Predict: 0.0
#           Else (feature 16 > 5.0E-4)
#            Predict: 1.0
#          Else (feature 16 > 0.0105)
#           Predict: 2.0
#         Else (feature 42 > 2.5)
#          Predict: 2.0
#        Else (feature 18 > 29.5)
#         If (feature 19 <= 29.535)
#          If (feature 36 <= 44.5)
#           If (feature 18 <= 78.5)
#            If (feature 47 <= 22.5)
#             Predict: 1.0
#            Else (feature 47 > 22.5)
#             Predict: 2.0
#           Else (feature 18 > 78.5)
#            If (feature 16 <= 1.4390000286100002)
#             Predict: 0.0
#            Else (feature 16 > 1.4390000286100002)
#             Predict: 2.0
#          Else (feature 36 > 44.5)
#           If (feature 41 <= 4.5)
#            If (feature 16 <= 1.976)
#             Predict: 1.0
#            Else (feature 16 > 1.976)
#             Predict: 2.0
#           Else (feature 41 > 4.5)
#            Predict: 1.0
#         Else (feature 19 > 29.535)
#          If (feature 32 <= 0.5)
#           Predict: 1.0
#          Else (feature 32 > 0.5)
#           Predict: 0.0
#       Else (feature 1 > 0.5)
#        If (feature 23 <= 0.5)
#         If (feature 16 <= 5.313000000000001)
#          If (feature 36 <= 50.5)
#           If (feature 17 <= 51.45)
#            If (feature 19 <= 29.884999999999998)
#             Predict: 0.0
#            Else (feature 19 > 29.884999999999998)
#             Predict: 1.0
#           Else (feature 17 > 51.45)
#            If (feature 21 <= 16.55)
#             Predict: 1.0
#            Else (feature 21 > 16.55)
#             Predict: 0.0
#          Else (feature 36 > 50.5)
#           If (feature 18 <= 48.5)
#            Predict: 1.0
#           Else (feature 18 > 48.5)
#            If (feature 39 <= 9.5)
#             Predict: 1.0
#            Else (feature 39 > 9.5)
#             Predict: 0.0
#         Else (feature 16 > 5.313000000000001)
#          If (feature 18 <= 38.5)
#           Predict: 1.0
#          Else (feature 18 > 38.5)
#           If (feature 35 <= 2.5)
#            Predict: 2.0
#           Else (feature 35 > 2.5)
#            Predict: 1.0
#        Else (feature 23 > 0.5)
#         If (feature 25 <= 0.5)
#          If (feature 34 <= 0.5)
#           If (feature 19 <= 29.975)
#            Predict: 0.0
#           Else (feature 19 > 29.975)
#            Predict: 1.0
#          Else (feature 34 > 0.5)
#           Predict: 0.0
#         Else (feature 25 > 0.5)
#          Predict: 0.0
#      Else (feature 38 > 0.5)
#       If (feature 31 <= 0.5)
#        If (feature 16 <= 0.0105)
#         If (feature 0 <= 0.5)
#          If (feature 17 <= 64.1)
#           If (feature 3 <= 0.5)
#            Predict: 0.0
#           Else (feature 3 > 0.5)
#            Predict: 1.0
#          Else (feature 17 > 64.1)
#           If (feature 40 <= 2.5)
#            If (feature 25 <= 0.5)
#             Predict: 1.0
#            Else (feature 25 > 0.5)
#             Predict: 0.0
#           Else (feature 40 > 2.5)
#            If (feature 14 <= 0.5)
#             Predict: 0.0
#            Else (feature 14 > 0.5)
#             Predict: 1.0
#         Else (feature 0 > 0.5)
#          Predict: 0.0
#        Else (feature 16 > 0.0105)
#         If (feature 41 <= 5.5)
#          If (feature 11 <= 0.5)
#           If (feature 17 <= 48.95)
#            Predict: 0.0
#           Else (feature 17 > 48.95)
#            Predict: 1.0
#          Else (feature 11 > 0.5)
#           If (feature 19 <= 29.994999999999997)
#            Predict: 0.0
#           Else (feature 19 > 29.994999999999997)
#            Predict: 1.0
#         Else (feature 41 > 5.5)
#          Predict: 0.0
#       Else (feature 31 > 0.5)
#        Predict: 0.0
#     Else (feature 37 > 0.5)
#      If (feature 16 <= 5.0E-4)
#       If (feature 17 <= 57.1)
#        If (feature 37 <= 1.5)
#         If (feature 20 <= 5.5)
#          If (feature 17 <= 28.65)
#           If (feature 8 <= 0.5)
#            If (feature 35 <= 1.5)
#             Predict: 0.0
#            Else (feature 35 > 1.5)
#             Predict: 1.0
#           Else (feature 8 > 0.5)
#            Predict: 0.0
#          Else (feature 17 > 28.65)
#           Predict: 0.0
#         Else (feature 20 > 5.5)
#          If (feature 41 <= 0.5)
#           If (feature 14 <= 0.5)
#            If (feature 35 <= 1.5)
#             Predict: 0.0
#            Else (feature 35 > 1.5)
#             Predict: 2.0
#           Else (feature 14 > 0.5)
#            Predict: 0.0
#          Else (feature 41 > 0.5)
#           If (feature 1 <= 0.5)
#            If (feature 18 <= 99.5)
#             Predict: 0.0
#            Else (feature 18 > 99.5)
#             Predict: 2.0
#           Else (feature 1 > 0.5)
#            If (feature 17 <= 33.05)
#             Predict: 2.0
#            Else (feature 17 > 33.05)
#             Predict: 0.0
#        Else (feature 37 > 1.5)
#         If (feature 19 <= 29.744999999999997)
#          If (feature 18 <= 90.5)
#           If (feature 41 <= 4.5)
#            If (feature 21 <= 10.2)
#             Predict: 0.0
#            Else (feature 21 > 10.2)
#             Predict: 1.0
#           Else (feature 41 > 4.5)
#            Predict: 1.0
#          Else (feature 18 > 90.5)
#           Predict: 1.0
#         Else (feature 19 > 29.744999999999997)
#          If (feature 5 <= 0.5)
#           Predict: 1.0
#          Else (feature 5 > 0.5)
#           Predict: 0.0
#       Else (feature 17 > 57.1)
#        If (feature 1 <= 0.5)
#         If (feature 19 <= 29.935000000000002)
#          If (feature 41 <= 4.5)
#           If (feature 8 <= 0.5)
#            If (feature 22 <= 0.015)
#             Predict: 0.0
#            Else (feature 22 > 0.015)
#             Predict: 1.0
#           Else (feature 8 > 0.5)
#            Predict: 1.0
#          Else (feature 41 > 4.5)
#           Predict: 0.0
#         Else (feature 19 > 29.935000000000002)
#          If (feature 18 <= 72.5)
#           If (feature 11 <= 0.5)
#            If (feature 42 <= 0.5)
#             Predict: 1.0
#            Else (feature 42 > 0.5)
#             Predict: 0.0
#           Else (feature 11 > 0.5)
#            Predict: 0.0
#          Else (feature 18 > 72.5)
#           If (feature 37 <= 1.5)
#            If (feature 22 <= 0.055)
#             Predict: 2.0
#            Else (feature 22 > 0.055)
#             Predict: 1.0
#           Else (feature 37 > 1.5)
#            Predict: 1.0
#        Else (feature 1 > 0.5)
#         If (feature 34 <= 0.5)
#          Predict: 2.0
#         Else (feature 34 > 0.5)
#          Predict: 0.0
#      Else (feature 16 > 5.0E-4)
#       If (feature 47 <= 21.5)
#        If (feature 16 <= 1.4390000286100002)
#         If (feature 22 <= 0.035)
#          If (feature 10 <= 0.5)
#           If (feature 25 <= 0.5)
#            Predict: 2.0
#           Else (feature 25 > 0.5)
#            If (feature 17 <= 40.9)
#             Predict: 0.0
#            Else (feature 17 > 40.9)
#             Predict: 2.0
#          Else (feature 10 > 0.5)
#           If (feature 20 <= 0.225)
#            Predict: 0.0
#           Else (feature 20 > 0.225)
#            Predict: 1.0
#         Else (feature 22 > 0.035)
#          If (feature 18 <= 85.5)
#           Predict: 1.0
#          Else (feature 18 > 85.5)
#           If (feature 39 <= 11.5)
#            Predict: 2.0
#           Else (feature 39 > 11.5)
#            If (feature 21 <= 8.55)
#             Predict: 2.0
#            Else (feature 21 > 8.55)
#             Predict: 1.0
#        Else (feature 16 > 1.4390000286100002)
#         If (feature 42 <= 0.5)
#          Predict: 0.0
#         Else (feature 42 > 0.5)
#          If (feature 39 <= 0.5)
#           If (feature 17 <= 72.95)
#            Predict: 2.0
#           Else (feature 17 > 72.95)
#            If (feature 41 <= 3.5)
#             Predict: 1.0
#            Else (feature 41 > 3.5)
#             Predict: 2.0
#          Else (feature 39 > 0.5)
#           Predict: 2.0
#       Else (feature 47 > 21.5)
#        If (feature 23 <= 0.5)
#         If (feature 18 <= 34.5)
#          If (feature 47 <= 22.5)
#           If (feature 36 <= 43.5)
#            If (feature 21 <= 4.8)
#             Predict: 0.0
#            Else (feature 21 > 4.8)
#             Predict: 2.0
#           Else (feature 36 > 43.5)
#            If (feature 1 <= 0.5)
#             Predict: 1.0
#            Else (feature 1 > 0.5)
#             Predict: 0.0
#          Else (feature 47 > 22.5)
#           If (feature 17 <= 59.1)
#            Predict: 1.0
#           Else (feature 17 > 59.1)
#            Predict: 2.0
#         Else (feature 18 > 34.5)
#          If (feature 34 <= 0.5)
#           Predict: 2.0
#          Else (feature 34 > 0.5)
#           If (feature 37 <= 1.5)
#            Predict: 2.0
#           Else (feature 37 > 1.5)
#            Predict: 1.0
#        Else (feature 23 > 0.5)
#         If (feature 40 <= 1.5)
#          Predict: 1.0
#         Else (feature 40 > 1.5)
#          Predict: 0.0
#   Else (feature 35 > 3.5)
#    If (feature 23 <= 0.5)
#     If (feature 37 <= 0.5)
#      If (feature 31 <= 0.5)
#       If (feature 38 <= 0.5)
#        If (feature 42 <= 0.5)
#         If (feature 34 <= 0.5)
#          If (feature 41 <= 4.5)
#           If (feature 25 <= 0.5)
#            If (feature 11 <= 0.5)
#             Predict: 1.0
#            Else (feature 11 > 0.5)
#             Predict: 0.0
#           Else (feature 25 > 0.5)
#            Predict: 0.0
#          Else (feature 41 > 4.5)
#           If (feature 4 <= 0.5)
#            Predict: 1.0
#           Else (feature 4 > 0.5)
#            If (feature 25 <= 0.5)
#             Predict: 1.0
#            Else (feature 25 > 0.5)
#             Predict: 0.0
#         Else (feature 34 > 0.5)
#          If (feature 19 <= 29.535)
#           If (feature 19 <= 29.085)
#            If (feature 16 <= 1.4390000286100002)
#             Predict: 0.0
#            Else (feature 16 > 1.4390000286100002)
#             Predict: 2.0
#           Else (feature 19 > 29.085)
#            Predict: 0.0
#          Else (feature 19 > 29.535)
#           If (feature 25 <= 0.5)
#            If (feature 16 <= 0.4135)
#             Predict: 0.0
#            Else (feature 16 > 0.4135)
#             Predict: 1.0
#           Else (feature 25 > 0.5)
#            Predict: 0.0
#        Else (feature 42 > 0.5)
#         If (feature 34 <= 0.5)
#          If (feature 11 <= 0.5)
#           If (feature 16 <= 1.070000026225)
#            Predict: 1.0
#           Else (feature 16 > 1.070000026225)
#            If (feature 19 <= 29.744999999999997)
#             Predict: 2.0
#            Else (feature 19 > 29.744999999999997)
#             Predict: 1.0
#          Else (feature 11 > 0.5)
#           If (feature 35 <= 5.5)
#            Predict: 1.0
#           Else (feature 35 > 5.5)
#            If (feature 25 <= 0.5)
#             Predict: 1.0
#            Else (feature 25 > 0.5)
#             Predict: 0.0
#         Else (feature 34 > 0.5)
#          If (feature 22 <= 0.055)
#           If (feature 41 <= 4.5)
#            Predict: 0.0
#           Else (feature 41 > 4.5)
#            Predict: 1.0
#          Else (feature 22 > 0.055)
#           Predict: 1.0
#       Else (feature 38 > 0.5)
#        If (feature 45 <= 0.5)
#         If (feature 22 <= 0.015)
#          If (feature 41 <= 4.5)
#           If (feature 27 <= 0.5)
#            Predict: 0.0
#           Else (feature 27 > 0.5)
#            If (feature 36 <= 34.5)
#             Predict: 0.0
#            Else (feature 36 > 34.5)
#             Predict: 1.0
#          Else (feature 41 > 4.5)
#           If (feature 16 <= 0.17149999999999999)
#            Predict: 0.0
#           Else (feature 16 > 0.17149999999999999)
#            If (feature 33 <= 0.5)
#             Predict: 1.0
#            Else (feature 33 > 0.5)
#             Predict: 0.0
#         Else (feature 22 > 0.015)
#          If (feature 42 <= 0.5)
#           Predict: 0.0
#          Else (feature 42 > 0.5)
#           If (feature 40 <= 2.5)
#            Predict: 0.0
#           Else (feature 40 > 2.5)
#            If (feature 39 <= 16.5)
#             Predict: 0.0
#            Else (feature 39 > 16.5)
#             Predict: 1.0
#        Else (feature 45 > 0.5)
#         If (feature 27 <= 0.5)
#          If (feature 16 <= 0.0835)
#           If (feature 36 <= 50.5)
#            Predict: 0.0
#           Else (feature 36 > 50.5)
#            If (feature 17 <= 73.95)
#             Predict: 0.0
#            Else (feature 17 > 73.95)
#             Predict: 1.0
#          Else (feature 16 > 0.0835)
#           If (feature 16 <= 1.4390000286100002)
#            If (feature 21 <= 18.2)
#             Predict: 1.0
#            Else (feature 21 > 18.2)
#             Predict: 2.0
#           Else (feature 16 > 1.4390000286100002)
#            If (feature 36 <= 46.5)
#             Predict: 0.0
#            Else (feature 36 > 46.5)
#             Predict: 2.0
#         Else (feature 27 > 0.5)
#          If (feature 14 <= 0.5)
#           If (feature 21 <= 4.05)
#            Predict: 1.0
#           Else (feature 21 > 4.05)
#            Predict: 0.0
#          Else (feature 14 > 0.5)
#           If (feature 47 <= 2.5)
#            Predict: 0.0
#           Else (feature 47 > 2.5)
#            Predict: 1.0
#      Else (feature 31 > 0.5)
#       If (feature 42 <= 0.5)
#        If (feature 45 <= 0.5)
#         If (feature 27 <= 0.5)
#          If (feature 25 <= 0.5)
#           If (feature 29 <= 0.5)
#            Predict: 0.0
#           Else (feature 29 > 0.5)
#            If (feature 39 <= 16.5)
#             Predict: 1.0
#            Else (feature 39 > 16.5)
#             Predict: 2.0
#          Else (feature 25 > 0.5)
#           Predict: 0.0
#         Else (feature 27 > 0.5)
#          If (feature 39 <= 11.5)
#           If (feature 35 <= 10.5)
#            If (feature 21 <= 4.05)
#             Predict: 0.0
#            Else (feature 21 > 4.05)
#             Predict: 1.0
#           Else (feature 35 > 10.5)
#            Predict: 1.0
#          Else (feature 39 > 11.5)
#           Predict: 0.0
#        Else (feature 45 > 0.5)
#         If (feature 19 <= 29.744999999999997)
#          If (feature 41 <= 4.5)
#           Predict: 0.0
#          Else (feature 41 > 4.5)
#           If (feature 21 <= 6.45)
#            Predict: 0.0
#           Else (feature 21 > 6.45)
#            Predict: 1.0
#         Else (feature 19 > 29.744999999999997)
#          If (feature 27 <= 0.5)
#           Predict: 0.0
#          Else (feature 27 > 0.5)
#           If (feature 35 <= 18.5)
#            Predict: 0.0
#           Else (feature 35 > 18.5)
#            Predict: 1.0
#       Else (feature 42 > 0.5)
#        If (feature 34 <= 0.5)
#         If (feature 17 <= 84.1)
#          If (feature 18 <= 67.5)
#           If (feature 9 <= 0.5)
#            If (feature 40 <= 0.5)
#             Predict: 0.0
#            Else (feature 40 > 0.5)
#             Predict: 1.0
#           Else (feature 9 > 0.5)
#            Predict: 1.0
#          Else (feature 18 > 67.5)
#           If (feature 29 <= 0.5)
#            Predict: 0.0
#           Else (feature 29 > 0.5)
#            If (feature 25 <= 0.5)
#             Predict: 1.0
#            Else (feature 25 > 0.5)
#             Predict: 0.0
#         Else (feature 17 > 84.1)
#          If (feature 19 <= 29.965)
#           If (feature 17 <= 90.25)
#            If (feature 36 <= 18.5)
#             Predict: 0.0
#            Else (feature 36 > 18.5)
#             Predict: 1.0
#           Else (feature 17 > 90.25)
#            Predict: 0.0
#          Else (feature 19 > 29.965)
#           Predict: 0.0
#        Else (feature 34 > 0.5)
#         If (feature 29 <= 0.5)
#          If (feature 18 <= 20.5)
#           Predict: 1.0
#          Else (feature 18 > 20.5)
#           If (feature 35 <= 6.5)
#            If (feature 11 <= 0.5)
#             Predict: 1.0
#            Else (feature 11 > 0.5)
#             Predict: 0.0
#           Else (feature 35 > 6.5)
#            Predict: 0.0
#         Else (feature 29 > 0.5)
#          If (feature 17 <= 53.8)
#           If (feature 21 <= 6.95)
#            If (feature 1 <= 0.5)
#             Predict: 1.0
#            Else (feature 1 > 0.5)
#             Predict: 0.0
#           Else (feature 21 > 6.95)
#            Predict: 1.0
#          Else (feature 17 > 53.8)
#           If (feature 18 <= 74.5)
#            Predict: 0.0
#           Else (feature 18 > 74.5)
#            If (feature 36 <= 41.5)
#             Predict: 1.0
#            Else (feature 36 > 41.5)
#             Predict: 0.0
#     Else (feature 37 > 0.5)
#      If (feature 42 <= 0.5)
#       If (feature 11 <= 0.5)
#        If (feature 38 <= 0.5)
#         If (feature 40 <= 4.5)
#          If (feature 25 <= 0.5)
#           Predict: 1.0
#          Else (feature 25 > 0.5)
#           If (feature 17 <= 46.3)
#            If (feature 20 <= 11.0)
#             Predict: 0.0
#            Else (feature 20 > 11.0)
#             Predict: 1.0
#           Else (feature 17 > 46.3)
#            If (feature 16 <= 0.0105)
#             Predict: 0.0
#            Else (feature 16 > 0.0105)
#             Predict: 1.0
#         Else (feature 40 > 4.5)
#          If (feature 35 <= 5.5)
#           If (feature 36 <= 2.5)
#            Predict: 0.0
#           Else (feature 36 > 2.5)
#            Predict: 1.0
#          Else (feature 35 > 5.5)
#           If (feature 35 <= 7.5)
#            Predict: 1.0
#           Else (feature 35 > 7.5)
#            If (feature 34 <= 0.5)
#             Predict: 1.0
#            Else (feature 34 > 0.5)
#             Predict: 0.0
#        Else (feature 38 > 0.5)
#         If (feature 16 <= 0.2405)
#          If (feature 34 <= 0.5)
#           If (feature 21 <= 15.5)
#            Predict: 0.0
#           Else (feature 21 > 15.5)
#            If (feature 36 <= 4.5)
#             Predict: 1.0
#            Else (feature 36 > 4.5)
#             Predict: 0.0
#          Else (feature 34 > 0.5)
#           If (feature 8 <= 0.5)
#            Predict: 0.0
#           Else (feature 8 > 0.5)
#            Predict: 1.0
#         Else (feature 16 > 0.2405)
#          If (feature 35 <= 5.5)
#           Predict: 0.0
#          Else (feature 35 > 5.5)
#           If (feature 21 <= 7.5)
#            Predict: 1.0
#           Else (feature 21 > 7.5)
#            If (feature 36 <= 33.5)
#             Predict: 1.0
#            Else (feature 36 > 33.5)
#             Predict: 0.0
#       Else (feature 11 > 0.5)
#        If (feature 39 <= 15.5)
#         If (feature 47 <= 14.5)
#          If (feature 25 <= 0.5)
#           If (feature 36 <= 2.5)
#            If (feature 19 <= 29.085)
#             Predict: 2.0
#            Else (feature 19 > 29.085)
#             Predict: 0.0
#           Else (feature 36 > 2.5)
#            Predict: 1.0
#          Else (feature 25 > 0.5)
#           If (feature 41 <= 1.5)
#            If (feature 36 <= 43.5)
#             Predict: 0.0
#            Else (feature 36 > 43.5)
#             Predict: 1.0
#           Else (feature 41 > 1.5)
#            Predict: 0.0
#         Else (feature 47 > 14.5)
#          If (feature 34 <= 0.5)
#           If (feature 38 <= 0.5)
#            If (feature 29 <= 0.5)
#             Predict: 1.0
#            Else (feature 29 > 0.5)
#             Predict: 0.0
#           Else (feature 38 > 0.5)
#            Predict: 0.0
#          Else (feature 34 > 0.5)
#           Predict: 0.0
#        Else (feature 39 > 15.5)
#         If (feature 41 <= 2.5)
#          If (feature 17 <= 55.3)
#           If (feature 39 <= 16.5)
#            Predict: 0.0
#           Else (feature 39 > 16.5)
#            Predict: 1.0
#          Else (feature 17 > 55.3)
#           If (feature 18 <= 70.5)
#            Predict: 0.0
#           Else (feature 18 > 70.5)
#            If (feature 19 <= 29.855)
#             Predict: 0.0
#            Else (feature 19 > 29.855)
#             Predict: 1.0
#         Else (feature 41 > 2.5)
#          If (feature 41 <= 5.5)
#           If (feature 17 <= 53.8)
#            Predict: 1.0
#           Else (feature 17 > 53.8)
#            If (feature 18 <= 29.5)
#             Predict: 1.0
#            Else (feature 18 > 29.5)
#             Predict: 0.0
#          Else (feature 41 > 5.5)
#           Predict: 0.0
#      Else (feature 42 > 0.5)
#       If (feature 44 <= 0.5)
#        If (feature 11 <= 0.5)
#         If (feature 16 <= 0.8125)
#          If (feature 19 <= 30.055)
#           If (feature 38 <= 0.5)
#            If (feature 37 <= 1.5)
#             Predict: 2.0
#            Else (feature 37 > 1.5)
#             Predict: 1.0
#           Else (feature 38 > 0.5)
#            If (feature 37 <= 1.5)
#             Predict: 2.0
#            Else (feature 37 > 1.5)
#             Predict: 0.0
#          Else (feature 19 > 30.055)
#           If (feature 17 <= 51.45)
#            Predict: 2.0
#           Else (feature 17 > 51.45)
#            If (feature 16 <= 0.0165)
#             Predict: 0.0
#            Else (feature 16 > 0.0165)
#             Predict: 2.0
#         Else (feature 16 > 0.8125)
#          Predict: 2.0
#        Else (feature 11 > 0.5)
#         If (feature 40 <= 4.5)
#          If (feature 17 <= 51.45)
#           If (feature 36 <= 45.5)
#            If (feature 35 <= 7.5)
#             Predict: 0.0
#            Else (feature 35 > 7.5)
#             Predict: 2.0
#           Else (feature 36 > 45.5)
#            Predict: 2.0
#          Else (feature 17 > 51.45)
#           If (feature 37 <= 1.5)
#            Predict: 0.0
#           Else (feature 37 > 1.5)
#            If (feature 39 <= 13.5)
#             Predict: 1.0
#            Else (feature 39 > 13.5)
#             Predict: 0.0
#         Else (feature 40 > 4.5)
#          If (feature 41 <= 4.5)
#           If (feature 42 <= 1.5)
#            If (feature 19 <= 30.305)
#             Predict: 2.0
#            Else (feature 19 > 30.305)
#             Predict: 0.0
#           Else (feature 42 > 1.5)
#            If (feature 18 <= 85.5)
#             Predict: 1.0
#            Else (feature 18 > 85.5)
#             Predict: 0.0
#          Else (feature 41 > 4.5)
#           If (feature 19 <= 28.685000000000002)
#            If (feature 17 <= 78.69999999999999)
#             Predict: 2.0
#            Else (feature 17 > 78.69999999999999)
#             Predict: 0.0
#           Else (feature 19 > 28.685000000000002)
#            If (feature 19 <= 30.255000000000003)
#             Predict: 2.0
#            Else (feature 19 > 30.255000000000003)
#             Predict: 0.0
#       Else (feature 44 > 0.5)
#        If (feature 41 <= 4.5)
#         If (feature 21 <= 3.25)
#          If (feature 19 <= 29.535)
#           Predict: 2.0
#          Else (feature 19 > 29.535)
#           If (feature 17 <= 37.1)
#            If (feature 18 <= 96.5)
#             Predict: 2.0
#            Else (feature 18 > 96.5)
#             Predict: 0.0
#           Else (feature 17 > 37.1)
#            If (feature 17 <= 67.9)
#             Predict: 0.0
#            Else (feature 17 > 67.9)
#             Predict: 2.0
#         Else (feature 21 > 3.25)
#          If (feature 37 <= 1.5)
#           Predict: 2.0
#          Else (feature 37 > 1.5)
#           If (feature 19 <= 29.744999999999997)
#            If (feature 40 <= 6.5)
#             Predict: 0.0
#            Else (feature 40 > 6.5)
#             Predict: 1.0
#           Else (feature 19 > 29.744999999999997)
#            Predict: 1.0
#        Else (feature 41 > 4.5)
#         If (feature 31 <= 0.5)
#          If (feature 42 <= 1.5)
#           Predict: 2.0
#          Else (feature 42 > 1.5)
#           If (feature 21 <= 0.6)
#            If (feature 18 <= 53.5)
#             Predict: 1.0
#            Else (feature 18 > 53.5)
#             Predict: 0.0
#           Else (feature 21 > 0.6)
#            If (feature 35 <= 19.5)
#             Predict: 1.0
#            Else (feature 35 > 19.5)
#             Predict: 0.0
#         Else (feature 31 > 0.5)
#          If (feature 16 <= 5.0E-4)
#           If (feature 37 <= 1.5)
#            Predict: 0.0
#           Else (feature 37 > 1.5)
#            Predict: 1.0
#          Else (feature 16 > 5.0E-4)
#           If (feature 38 <= 0.5)
#            If (feature 21 <= 5.9)
#             Predict: 2.0
#            Else (feature 21 > 5.9)
#             Predict: 0.0
#           Else (feature 38 > 0.5)
#            Predict: 2.0
#    Else (feature 23 > 0.5)
#     If (feature 34 <= 0.5)
#      If (feature 16 <= 0.0135)
#       If (feature 37 <= 0.5)
#        If (feature 41 <= 4.5)
#         If (feature 18 <= 90.5)
#          If (feature 17 <= 76.9)
#           Predict: 0.0
#          Else (feature 17 > 76.9)
#           If (feature 42 <= 0.5)
#            Predict: 0.0
#           Else (feature 42 > 0.5)
#            If (feature 0 <= 0.5)
#             Predict: 0.0
#            Else (feature 0 > 0.5)
#             Predict: 1.0
#         Else (feature 18 > 90.5)
#          If (feature 10 <= 0.5)
#           Predict: 0.0
#          Else (feature 10 > 0.5)
#           If (feature 35 <= 8.5)
#            Predict: 0.0
#           Else (feature 35 > 8.5)
#            Predict: 1.0
#        Else (feature 41 > 4.5)
#         If (feature 35 <= 7.5)
#          If (feature 36 <= 36.5)
#           If (feature 25 <= 0.5)
#            If (feature 19 <= 29.744999999999997)
#             Predict: 0.0
#            Else (feature 19 > 29.744999999999997)
#             Predict: 1.0
#           Else (feature 25 > 0.5)
#            Predict: 0.0
#          Else (feature 36 > 36.5)
#           Predict: 0.0
#         Else (feature 35 > 7.5)
#          If (feature 36 <= 49.5)
#           If (feature 18 <= 81.5)
#            Predict: 0.0
#           Else (feature 18 > 81.5)
#            If (feature 16 <= 5.0E-4)
#             Predict: 0.0
#            Else (feature 16 > 5.0E-4)
#             Predict: 1.0
#          Else (feature 36 > 49.5)
#           If (feature 44 <= 0.5)
#            Predict: 1.0
#           Else (feature 44 > 0.5)
#            If (feature 1 <= 0.5)
#             Predict: 1.0
#            Else (feature 1 > 0.5)
#             Predict: 0.0
#       Else (feature 37 > 0.5)
#        If (feature 16 <= 0.0025)
#         If (feature 17 <= 59.1)
#          If (feature 39 <= 4.5)
#           If (feature 36 <= 49.5)
#            If (feature 31 <= 0.5)
#             Predict: 0.0
#            Else (feature 31 > 0.5)
#             Predict: 1.0
#           Else (feature 36 > 49.5)
#            Predict: 2.0
#          Else (feature 39 > 4.5)
#           If (feature 41 <= 1.5)
#            Predict: 0.0
#           Else (feature 41 > 1.5)
#            If (feature 36 <= 40.5)
#             Predict: 2.0
#            Else (feature 36 > 40.5)
#             Predict: 0.0
#         Else (feature 17 > 59.1)
#          If (feature 40 <= 4.5)
#           If (feature 31 <= 0.5)
#            Predict: 0.0
#           Else (feature 31 > 0.5)
#            If (feature 38 <= 0.5)
#             Predict: 1.0
#            Else (feature 38 > 0.5)
#             Predict: 0.0
#          Else (feature 40 > 4.5)
#           If (feature 21 <= 8.05)
#            If (feature 21 <= 7.5)
#             Predict: 0.0
#            Else (feature 21 > 7.5)
#             Predict: 1.0
#           Else (feature 21 > 8.05)
#            If (feature 41 <= 1.5)
#             Predict: 0.0
#            Else (feature 41 > 1.5)
#             Predict: 2.0
#        Else (feature 16 > 0.0025)
#         If (feature 20 <= 3.25)
#          Predict: 2.0
#         Else (feature 20 > 3.25)
#          If (feature 47 <= 6.5)
#           If (feature 13 <= 0.5)
#            If (feature 17 <= 37.1)
#             Predict: 1.0
#            Else (feature 17 > 37.1)
#             Predict: 0.0
#           Else (feature 13 > 0.5)
#            Predict: 0.0
#          Else (feature 47 > 6.5)
#           If (feature 1 <= 0.5)
#            If (feature 43 <= 0.5)
#             Predict: 2.0
#            Else (feature 43 > 0.5)
#             Predict: 0.0
#           Else (feature 1 > 0.5)
#            If (feature 25 <= 0.5)
#             Predict: 2.0
#            Else (feature 25 > 0.5)
#             Predict: 0.0
#      Else (feature 16 > 0.0135)
#       If (feature 9 <= 0.5)
#        If (feature 27 <= 0.5)
#         If (feature 47 <= 3.5)
#          If (feature 11 <= 0.5)
#           If (feature 36 <= 5.5)
#            If (feature 42 <= 0.5)
#             Predict: 1.0
#            Else (feature 42 > 0.5)
#             Predict: 0.0
#           Else (feature 36 > 5.5)
#            Predict: 2.0
#          Else (feature 11 > 0.5)
#           Predict: 2.0
#         Else (feature 47 > 3.5)
#          If (feature 37 <= 0.5)
#           If (feature 18 <= 29.5)
#            Predict: 1.0
#           Else (feature 18 > 29.5)
#            Predict: 0.0
#          Else (feature 37 > 0.5)
#           If (feature 36 <= 7.5)
#            If (feature 36 <= 5.5)
#             Predict: 2.0
#            Else (feature 36 > 5.5)
#             Predict: 0.0
#           Else (feature 36 > 7.5)
#            Predict: 2.0
#        Else (feature 27 > 0.5)
#         If (feature 18 <= 67.5)
#          If (feature 35 <= 18.5)
#           If (feature 19 <= 29.535)
#            Predict: 1.0
#           Else (feature 19 > 29.535)
#            If (feature 36 <= 15.5)
#             Predict: 1.0
#            Else (feature 36 > 15.5)
#             Predict: 0.0
#          Else (feature 35 > 18.5)
#           Predict: 1.0
#         Else (feature 18 > 67.5)
#          If (feature 17 <= 67.9)
#           If (feature 36 <= 38.5)
#            Predict: 0.0
#           Else (feature 36 > 38.5)
#            Predict: 1.0
#          Else (feature 17 > 67.9)
#           Predict: 2.0
#       Else (feature 9 > 0.5)
#        If (feature 16 <= 0.2405)
#         If (feature 31 <= 0.5)
#          If (feature 36 <= 4.5)
#           Predict: 1.0
#          Else (feature 36 > 4.5)
#           If (feature 16 <= 0.0835)
#            Predict: 0.0
#           Else (feature 16 > 0.0835)
#            If (feature 40 <= 0.5)
#             Predict: 1.0
#            Else (feature 40 > 0.5)
#             Predict: 0.0
#         Else (feature 31 > 0.5)
#          If (feature 20 <= 3.25)
#           If (feature 20 <= 1.1)
#            Predict: 0.0
#           Else (feature 20 > 1.1)
#            Predict: 1.0
#          Else (feature 20 > 3.25)
#           Predict: 2.0
#        Else (feature 16 > 0.2405)
#         If (feature 19 <= 29.744999999999997)
#          If (feature 4 <= 0.5)
#           Predict: 0.0
#          Else (feature 4 > 0.5)
#           Predict: 2.0
#         Else (feature 19 > 29.744999999999997)
#          Predict: 0.0
#     Else (feature 34 > 0.5)
#      If (feature 42 <= 0.5)
#       If (feature 16 <= 0.6325000000000001)
#        If (feature 1 <= 0.5)
#         If (feature 37 <= 0.5)
#          If (feature 41 <= 4.5)
#           Predict: 0.0
#          Else (feature 41 > 4.5)
#           If (feature 17 <= 40.9)
#            If (feature 21 <= 0.6)
#             Predict: 1.0
#            Else (feature 21 > 0.6)
#             Predict: 0.0
#           Else (feature 17 > 40.9)
#            Predict: 0.0
#         Else (feature 37 > 0.5)
#          If (feature 0 <= 0.5)
#           If (feature 17 <= 59.1)
#            If (feature 40 <= 3.5)
#             Predict: 1.0
#            Else (feature 40 > 3.5)
#             Predict: 0.0
#           Else (feature 17 > 59.1)
#            Predict: 0.0
#          Else (feature 0 > 0.5)
#           Predict: 0.0
#        Else (feature 1 > 0.5)
#         If (feature 40 <= 1.5)
#          If (feature 35 <= 17.5)
#           Predict: 0.0
#          Else (feature 35 > 17.5)
#           If (feature 41 <= 0.5)
#            If (feature 21 <= 8.55)
#             Predict: 0.0
#            Else (feature 21 > 8.55)
#             Predict: 1.0
#           Else (feature 41 > 0.5)
#            Predict: 0.0
#         Else (feature 40 > 1.5)
#          If (feature 47 <= 18.5)
#           Predict: 0.0
#          Else (feature 47 > 18.5)
#           If (feature 39 <= 4.5)
#            Predict: 0.0
#           Else (feature 39 > 4.5)
#            If (feature 18 <= 50.5)
#             Predict: 1.0
#            Else (feature 18 > 50.5)
#             Predict: 0.0
#       Else (feature 16 > 0.6325000000000001)
#        If (feature 18 <= 45.5)
#         Predict: 0.0
#        Else (feature 18 > 45.5)
#         Predict: 1.0
#      Else (feature 42 > 0.5)
#       If (feature 16 <= 0.0165)
#        If (feature 42 <= 1.5)
#         If (feature 25 <= 0.5)
#          If (feature 18 <= 50.5)
#           If (feature 35 <= 17.5)
#            Predict: 0.0
#           Else (feature 35 > 17.5)
#            If (feature 31 <= 0.5)
#             Predict: 1.0
#            Else (feature 31 > 0.5)
#             Predict: 0.0
#          Else (feature 18 > 50.5)
#           If (feature 16 <= 5.0E-4)
#            If (feature 19 <= 29.835)
#             Predict: 2.0
#            Else (feature 19 > 29.835)
#             Predict: 0.0
#           Else (feature 16 > 5.0E-4)
#            If (feature 0 <= 0.5)
#             Predict: 2.0
#            Else (feature 0 > 0.5)
#             Predict: 0.0
#         Else (feature 25 > 0.5)
#          If (feature 41 <= 3.5)
#           If (feature 41 <= 0.5)
#            If (feature 18 <= 53.5)
#             Predict: 1.0
#            Else (feature 18 > 53.5)
#             Predict: 2.0
#           Else (feature 41 > 0.5)
#            If (feature 47 <= 4.5)
#             Predict: 0.0
#            Else (feature 47 > 4.5)
#             Predict: 2.0
#          Else (feature 41 > 3.5)
#           If (feature 19 <= 30.015)
#            If (feature 40 <= 0.5)
#             Predict: 2.0
#            Else (feature 40 > 0.5)
#             Predict: 0.0
#           Else (feature 19 > 30.015)
#            If (feature 47 <= 9.5)
#             Predict: 2.0
#            Else (feature 47 > 9.5)
#             Predict: 1.0
#        Else (feature 42 > 1.5)
#         If (feature 25 <= 0.5)
#          If (feature 18 <= 45.5)
#           If (feature 41 <= 3.5)
#            If (feature 21 <= 4.05)
#             Predict: 0.0
#            Else (feature 21 > 4.05)
#             Predict: 1.0
#           Else (feature 41 > 3.5)
#            Predict: 0.0
#          Else (feature 18 > 45.5)
#           If (feature 17 <= 80.15)
#            Predict: 0.0
#           Else (feature 17 > 80.15)
#            If (feature 39 <= 4.5)
#             Predict: 1.0
#            Else (feature 39 > 4.5)
#             Predict: 0.0
#         Else (feature 25 > 0.5)
#          If (feature 31 <= 0.5)
#           If (feature 46 <= 0.5)
#            If (feature 36 <= 48.5)
#             Predict: 0.0
#            Else (feature 36 > 48.5)
#             Predict: 1.0
#           Else (feature 46 > 0.5)
#            If (feature 17 <= 55.3)
#             Predict: 0.0
#            Else (feature 17 > 55.3)
#             Predict: 1.0
#          Else (feature 31 > 0.5)
#           If (feature 41 <= 0.5)
#            If (feature 47 <= 0.5)
#             Predict: 1.0
#            Else (feature 47 > 0.5)
#             Predict: 0.0
#           Else (feature 41 > 0.5)
#            Predict: 0.0
#       Else (feature 16 > 0.0165)
#        If (feature 25 <= 0.5)
#         If (feature 0 <= 0.5)
#          If (feature 21 <= 5.9)
#           If (feature 42 <= 2.5)
#            If (feature 39 <= 9.5)
#             Predict: 0.0
#            Else (feature 39 > 9.5)
#             Predict: 1.0
#           Else (feature 42 > 2.5)
#            Predict: 0.0
#          Else (feature 21 > 5.9)
#           If (feature 16 <= 0.8125)
#            If (feature 41 <= 4.5)
#             Predict: 2.0
#            Else (feature 41 > 4.5)
#             Predict: 0.0
#           Else (feature 16 > 0.8125)
#            Predict: 0.0
#         Else (feature 0 > 0.5)
#          If (feature 31 <= 0.5)
#           If (feature 36 <= 5.5)
#            If (feature 41 <= 1.5)
#             Predict: 0.0
#            Else (feature 41 > 1.5)
#             Predict: 1.0
#           Else (feature 36 > 5.5)
#            If (feature 17 <= 90.25)
#             Predict: 2.0
#            Else (feature 17 > 90.25)
#             Predict: 0.0
#          Else (feature 31 > 0.5)
#           Predict: 2.0
#        Else (feature 25 > 0.5)
#         If (feature 20 <= 7.5)
#          If (feature 16 <= 0.0835)
#           If (feature 29 <= 0.5)
#            Predict: 0.0
#           Else (feature 29 > 0.5)
#            Predict: 2.0
#          Else (feature 16 > 0.0835)
#           If (feature 41 <= 0.5)
#            Predict: 1.0
#           Else (feature 41 > 0.5)
#            Predict: 0.0
#         Else (feature 20 > 7.5)
#          If (feature 19 <= 29.884999999999998)
#           If (feature 36 <= 46.5)
#            Predict: 2.0
#           Else (feature 36 > 46.5)
#            Predict: 0.0
#          Else (feature 19 > 29.884999999999998)
#           If (feature 17 <= 82.1)
#            Predict: 2.0
#           Else (feature 17 > 82.1)
#            If (feature 16 <= 0.17149999999999999)
#             Predict: 0.0
#            Else (feature 16 > 0.17149999999999999)
#             Predict: 1.0

# %% [markdown]
# # Decision Tree Base Model Multiclass Classification

# %%
# Create initial Decision Tree Model

dt = DecisionTreeClassifier(labelCol="label", featuresCol="features",seed=42)

# Creating pipeline for DT Base Model 

dt_pipe = Pipeline(stages=[label_stringIdx, va, dt])

# Train DT Base model with Training Data

dtModel = dt_pipe.fit(us_train_cat)

# %%
# Multiclass Evaluator to evaluate the performance of the model 

from pyspark.ml.evaluation import MulticlassClassificationEvaluator

evaluator_dt = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy")

# %%
# Transform Test data using Fitted Pipeline Built earlier for prediction of Test data

pred_dt = dtModel.transform(us_test_cat)

# %%
# Evaluation of model using Multiclass Evaluator on Test data

print("Accuracy",evaluator_dt.evaluate(pred_dt))
# Out:
# Accuracy 0.550150781461279

# %%
# Prediction output from the model to pandas

prediction_dt=pred_dt.toPandas()["prediction"]

# %%
# True Labels from test data for Target Variable

true_labels=us_test_cat.toPandas()["Severity"]

# %%
# Initializing Classification Report from sklearn

from sklearn.metrics import classification_report

# %%
# Classification Report Generation for all metrics display at once

print(classification_report(y_pred=prediction_dt,y_true=true_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.42      0.58    131571
#            1       0.48      0.81      0.60     58293
#            2       0.15      0.93      0.25      6115
#
#    micro avg       0.55      0.55      0.55    195979
#    macro avg       0.52      0.72      0.48    195979
# weighted avg       0.77      0.55      0.58    195979

# %%
# Creating Pandas Dataframe for Features and their Importance of DT Base Model for Multiclass Classification

pd.set_option('display.max_rows', None)
feat_imp_tuned_dt = pd.DataFrame(list(zip([i for i in us_train_cat.columns if i!='Severity'], dtModel.stages[-1].featureImportances)),
            columns = ['column', 'weight']).sort_values('weight',ascending=False)

# %%
# Plotting top 10 Features from Feature Importance of DT Base Model for Multiclass Classification

plt.figure(figsize=(10,10))
sns.barplot(x=feat_imp_tuned_dt['column'][:10], y=feat_imp_tuned_dt['weight'][:10],data=feat_imp_tuned_dt)
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Weights")
plt.title("Top 10 Features based on Importance from DT Multiclass Base Model")
# Out:
# Text(0.5,1,'Top 10 Features based on Importance from DT Multiclass Base Model')

# %% [markdown]
# # Decision Tree Grid Search Multiclass Classification

# %%
# Initializing DT Grid Pipeline 

dt_new = DecisionTreeClassifier(labelCol="label", featuresCol="features",seed=42)

# Creating pipeline for DT Grid Model 

dt_new_pipe = Pipeline(stages=[label_stringIdx, va, dt_new])

# Creating Grid Search for Hyper Parameter Tuning for DT Model

grid_dt = ParamGridBuilder().addGrid(dt_new.maxDepth, [10,15,30]).addGrid(dt_new.minInstancesPerNode, [500,1000,1500]).addGrid(dt_new.maxBins,[20,35,50]).build()

# Cross Validator Pipeline with 5 fold cv to fit the training data

cv1_dt = CrossValidator(estimator=dt_new_pipe,estimatorParamMaps=grid_dt, numFolds=5, evaluator=evaluator_dt,seed=42)

# %%
# Fitting the training data using the Cross Validator Pipeline 

dtModel_t = cv1_dt.fit(us_train_cat)

# %%
# Transform Test data using Cross Validation Pipeline Built earlier for prediction of Test data

pred_dtt = dtModel_t.transform(us_test_cat)

# %%
# Evaluation of Testing Data using Multiclass Evaluator 

print("Accuracy is",evaluator_dt.evaluate(pred_dtt))
# Out:
# Accuracy is 0.6206022073793621

# %%
# Decision Tree Hyper Parameter Values from Best Model

dtModel_t.bestModel.stages[-1].extractParamMap()
# Out:
# {Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='cacheNodeIds', doc='If false, the algorithm will pass trees to executors to match instances with nodes. If true, the algorithm will cache node IDs for each instance. Caching can speed up training of deeper trees.'): False,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='checkpointInterval', doc='set checkpoint interval (>= 1) or disable checkpoint (-1). E.g. 10 means that the cache will get checkpointed every 10 iterations. Note: this setting will be ignored if the checkpoint directory is not set in the SparkContext'): 10,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='featuresCol', doc='features column name'): 'features',
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='impurity', doc='Criterion used for information gain calculation (case-insensitive). Supported options: entropy, gini'): 'gini',
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='labelCol', doc='label column name'): 'label',
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='maxBins', doc='Max number of bins for discretizing continuous features.  Must be >=2 and >= number of categories for any categorical feature.'): 50,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='maxDepth', doc='Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes.'): 30,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='maxMemoryInMB', doc='Maximum memory in MB allocated to histogram aggregation.'): 256,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='minInfoGain', doc='Minimum information gain for a split to be considered at a tree node.'): 0.0,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='minInstancesPerNode', doc='Minimum number of instances each child must have after split.  If a split causes the left or right child to have fewer than minInstancesPerNode, the split will be discarded as invalid. Should be >= 1.'): 500,
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='predictionCol', doc='prediction column name'): 'prediction',
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='probabilityCol', doc='Column name for predicted class conditional probabilities. Note: Not all models output well-calibrated probability estimates! These probabilities should be treated as confidences, not precise probabilities'): 'probability',
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='rawPredictionCol', doc='raw prediction (a.k.a. confidence) column name'): 'rawPrediction',
#  Param(parent='DecisionTreeClassifier_89fe4e14d24e', name='seed', doc='random seed'): 42}

# %%
# Feature Importance Sparse Matrix

dtModel_t.bestModel.stages[-1].featureImportances
# Out:
# SparseVector(48, {0: 0.0002, 1: 0.0001, 11: 0.0049, 16: 0.1306, 17: 0.004, 18: 0.0018, 19: 0.0086, 20: 0.0001, 21: 0.002, 22: 0.0003, 25: 0.005, 27: 0.0052, 31: 0.0003, 32: 0.0069, 34: 0.0838, 35: 0.0039, 36: 0.0015, 37: 0.5438, 38: 0.1392, 39: 0.0009, 40: 0.008, 41: 0.0133, 42: 0.0179, 47: 0.0177})

# %%
# Prediction output from the model to pandas

prediction_dtt=pred_dtt.toPandas()["prediction"]

# %%
# True Labels from test data for Target Variable

true_labels=us_test_cat.toPandas()["Severity"]

# %%
# Initializing Classification Report from sklearn

from sklearn.metrics import classification_report

# %%
# Classification Report Generation for all metrics display at once

print(classification_report(y_pred=prediction_dtt,y_true=true_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.56      0.69    131571
#            1       0.52      0.73      0.61     58293
#            2       0.18      0.89      0.29      6115
#
#    micro avg       0.62      0.62      0.62    195979
#    macro avg       0.53      0.73      0.53    195979
# weighted avg       0.75      0.62      0.65    195979

# %%
# Creating Pandas Dataframe for Features and their Importance of DT Grid Model for Multiclass Classification

pd.set_option('display.max_rows', None)
feat_imp_tuned_dtt = pd.DataFrame(list(zip([i for i in us_train_cat.columns if i!='Severity'], dtModel_t.bestModel.stages[-1].featureImportances)),
            columns = ['column', 'weight']).sort_values('weight',ascending=False)

# %%
# Plotting top 10 Features from Feature Importance of DT Grid Model for Multiclass Classification

plt.figure(figsize=(10,10))
sns.barplot(x=feat_imp_tuned_dtt['column'][:10], y=feat_imp_tuned_dtt['weight'][:10],data=feat_imp_tuned_dtt)
plt.xticks(rotation=90)
plt.xlabel("Features")
plt.ylabel("Weights")
plt.title("Top 10 Features based on Importance from DT Multiclass tuned")
# Out:
# Text(0.5,1,'Top 10 Features based on Importance from DT Multiclass tuned')
